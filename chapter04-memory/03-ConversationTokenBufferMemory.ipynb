# %%
import os

import dotenv
from langchain_classic.chains.llm import LLMChain
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage, ChatMessage
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate, MessagesPlaceholder

from langchain_openai import ChatOpenAI
dotenv.load_dotenv()

llm = ChatOpenAI(
    model='qwen-plus',
    api_key=os.getenv('ALI_API_KEY'),
    base_url=os.getenv('ALI_API_URL'),
)

prompt_template = PromptTemplate(template="你是一个{role},你的名字叫{name}",input_variables=["role", "name"])

fmt = prompt_template.format(role="有帮助的助手", name="AIBOT")
print(fmt)
# Out:
# 你是一个有帮助的助手,你的名字叫AIBOT

# %%
# 1.导入相关包
from langchain_classic.memory import ConversationTokenBufferMemory
from langchain_openai import ChatOpenAI
# 2.创建大模型

llm = ChatOpenAI(
    model='qwen-plus',
    api_key=os.getenv('ALI_API_KEY'),
    base_url=os.getenv('ALI_API_URL'),
)
# 3.定义ConversationTokenBufferMemory对象
memory = ConversationTokenBufferMemory(
llm=llm,
max_token_limit=10 # 设置token上限
)
# 添加对话
memory.save_context({"input": "你好吗？"}, {"output": "我很好，谢谢！"})
memory.save_context({"input": "今天天气如何？"}, {"output": "晴天，25度"})
# 查看当前记忆
print(memory.load_memory_variables({}))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       3 from langchain_openai import ChatOpenAI
#       4 # 2.创建大模型
#       6 llm = ChatOpenAI(
#       7     model='qwen-plus',
# ----> 8     api_key=os.getenv('ALI_API_KEY'),
#       9     base_url=os.getenv('ALI_API_URL'),
#      10 )
#      11 # 3.定义ConversationTokenBufferMemory对象
#      12 memory = ConversationTokenBufferMemory(
#      13 llm=llm,
#      14 max_token_limit=10 # 设置token上限
#      15 )
#
# NameError: name 'os' is not defined

# %%
# 1.导入相关包
from langchain_classic.memory import ConversationTokenBufferMemory
from langchain_openai import ChatOpenAI
# 2.创建大模型


llm = ChatOpenAI(
    model='qwen-plus',
    api_key=os.getenv('ALI_API_KEY'),
    base_url=os.getenv('ALI_API_URL'),
)


# 3.定义ConversationTokenBufferMemory对象
memory = ConversationTokenBufferMemory(
llm=llm,
max_token_limit=50 # 设置token上限
)
# 添加对话
memory.save_context({"input": "你好吗？"}, {"output": "我很好，谢谢！"})
memory.save_context({"input": "今天天气如何？"}, {"output": "晴天，25度"})
# 查看当前记忆
print(memory.load_memory_variables({}))
# Out:
# C:\Users\oo\AppData\Local\Temp\ipykernel_30504\4124020236.py:15: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationTokenBufferMemory(
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[4], line 20
#      15 memory = ConversationTokenBufferMemory(
#      16 llm=llm,
#      17 max_token_limit=50 # 设置token上限
#      18 )
#      19 # 添加对话
# ---> 20 memory.save_context({"input": "你好吗？"}, {"output": "我很好，谢谢！"})
#      21 memory.save_context({"input": "今天天气如何？"}, {"output": "晴天，25度"})
#      22 # 查看当前记忆
#
# File ~\.conda\envs\ai\Lib\site-packages\langchain_classic\memory\token_buffer.py:66, in ConversationTokenBufferMemory.save_context(self, inputs, outputs)
#      64 # Prune buffer if it exceeds max token limit
#      65 buffer = self.chat_memory.messages
# ---> 66 curr_buffer_length = self.llm.get_num_tokens_from_messages(buffer)
#      67 if curr_buffer_length > self.max_token_limit:
#      68     pruned_memory = []
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_openai\chat_models\base.py:1761, in BaseChatOpenAI.get_num_tokens_from_messages(self, messages, tools)
#    1754 else:
#    1755     msg = (
#    1756         f"get_num_tokens_from_messages() is not presently implemented "
#    1757         f"for model {model}. See "
#    1758         "https://platform.openai.com/docs/guides/text-generation/managing-tokens"
#    1759         " for information on how messages are converted to tokens."
#    1760     )
# -> 1761     raise NotImplementedError(msg)
#    1762 num_tokens = 0
#    1763 messages_dict = [_convert_message_to_dict(m) for m in messages]
#
# NotImplementedError: get_num_tokens_from_messages() is not presently implemented for model qwen-plus. See https://platform.openai.com/docs/guides/text-generation/managing-tokens for information on how messages are converted to tokens.
